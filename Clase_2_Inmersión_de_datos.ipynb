# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexPrietoRomani/Inmersion_de_datos/blob/main/Clase_2_Inmersi%C3%B3n_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab  import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

inmuebles = pd.read_csv("/content/drive/MyDrive/Cursos/Inmersión de datos/Clase 2/inmuebles_bogota.csv")

inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %%
inmuebles.sample(10)
# Out:
#              Tipo                                     Descripcion  \
# 4208  Apartamento                 Apartamento en venta en Mazuren
# 8738  Apartamento             Apartamento en venta en Teusaquillo
# 1349  Apartamento                    Apartamento en venta en Usme
# 6031  Apartamento                 Apartamento en venta en Mazuren
# 8289  Apartamento                    Apartamento en venta en Bosa
# 6711  Apartamento      Apartamento en venta en Zona Noroccidental
# 6252  Apartamento      Apartamento en venta en Zona Noroccidental
# 7184  Apartamento                 Apartamento en venta en Kennedy
# 1795  Apartamento                Apartamento en venta en Hayuelos
# 5401  Apartamento  Apartamento en venta en Parque Central Bavaria
#
#       Habitaciones  Baños  Área                  Barrio  \
# 4208             3      3   134                 Mazuren
# 8738             1      1    37             Teusaquillo
# 1349             3      2    54                    Usme
# 6031             4      3    96                 Mazuren
# 8289             3      1    42                    Bosa
# 6711             3      2    60      Zona Noroccidental
# 6252             3      3   109      Zona Noroccidental
# 7184             3      1    48                 Kennedy
# 1795             3      2    77                Hayuelos
# 5401             1      2    68  Parque Central Bavaria
#
#                                          UPZ          Valor
# 4208                                El Prado  $ 980.000.000
# 8738                             Teusaquillo  $ 205.000.000
# 1349       USME: Alfonso López + Ciudad Usme  $ 150.000.000
# 6031                                El Prado  $ 300.000.000
# 8289                            Bosa Central  $ 120.000.000
# 6711      CHAPINERO: Pardo Rubio + Chapinero  $ 180.000.000
# 6252      CHAPINERO: Pardo Rubio + Chapinero  $ 515.000.000
# 7184                         Kennedy Central  $ 135.000.000
# 1795                                 Modelia  $ 360.000.000
# 5401  SANTA FE: Las Nieves + Sagrado Corazón  $ 460.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Área          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %% [markdown]
# Devolverá una separación
#
# Con expand = True nós devolverá un dataframe con dos columnas

# %%
valor = inmuebles.Valor.str.split(expand= True)

inmuebles["Moneda"] = valor[0]
inmuebles["Precio"] = valor[1]

inmuebles.sample(3)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 8694  Apartamento        Apartamento en venta en Chapinero             2
# 7759  Apartamento  Apartamento en venta en Chico Reservado             2
# 858   Apartamento         Apartamento en venta en Cedritos             3
#
#       Baños  Área           Barrio                                 UPZ  \
# 8694      3   150        Chapinero  CHAPINERO: Pardo Rubio + Chapinero
# 7759      2    69  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 858       2    95         Cedritos                             Usaquén
#
#                 Valor Moneda         Precio
# 8694  $ 1.995.000.046      $  1.995.000.046
# 7759    $ 580.000.000      $    580.000.000
# 858     $ 480.000.000      $    480.000.000

# %%
inmuebles["Precio"] = inmuebles["Precio"].str.replace(".","",regex=True)

inmuebles[["Precio","Barrio"]]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Área          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Transformar a tipo númerico la columna Precio

# %%
inmuebles["Precio_Millon"] = inmuebles.Precio.astype("float")/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Baños          9520 non-null   int64
#  4   Área           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Baños           Área  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option("display.precision",2)
pd.set_option("display.float_format",lambda x: "%.2f" %x)
inmuebles.describe()
# Out:
#        Habitaciones   Baños      Área  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Baños  Área    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Área == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Baños  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Área         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles["Precio_Millon"].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))
grafica = sns.histplot(data = inmuebles, x="Precio_Millon", kde = True, hue ="Tipo")
grafica.set_title("Distribución de los valores de los inmuebles en Bogotá")
plt.xlim((50,1000))
#plt.savefig("Ruta", format = "png")
plt.show()

# %% [markdown]
# 1.   **kde nos brindá la curva de densidad**
# 2.   **hue nos representa un tercer dato más; en esté caso el Tipo**

# %% [markdown]
# # **Respuesta del Desafio**

# %%
inmuebles[["Tipo","Área","Precio_Millon","Barrio"]]
# Out:
#              Tipo  Área  Precio_Millon                  Barrio
# 0     Apartamento    70         360.00      Zona Noroccidental
# 1            Casa   170         670.00                Castilla
# 2     Apartamento   144        1120.00         Chico Reservado
# 3     Apartamento   154         890.00                 Usaquén
# 4     Apartamento   128         970.00             Bella Suiza
# ...           ...   ...            ...                     ...
# 9515  Apartamento    70         290.00                 Kennedy
# 9516  Apartamento   100         670.00  Parque Central Bavaria
# 9517        Local   383         900.00                Restrepo
# 9518         Casa   183         335.00                Engativa
# 9519  Apartamento    52         144.99                 Tintala
#
# [9520 rows x 4 columns]

# %% [markdown]
# Graficando el precio/M2
#
# ---

# %%
inmuebles["Precio_M2"] = inmuebles.Precio_Millon.astype("float")/inmuebles.Área
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Baños          9520 non-null   int64
#  4   Área           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
#  11  Precio/M2      9520 non-null   float64
#  12  Precio_M2      9520 non-null   float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 967.0+ KB

# %%
inmuebles
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Baños  Área                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# 2                3      3   144         Chico Reservado
# 3                3      2   154                 Usaquén
# 4                2      3   128             Bella Suiza
# ...            ...    ...   ...                     ...
# 9515             3      2    70                 Kennedy
# 9516             2      2   100  Parque Central Bavaria
# 9517             8      6   383                Restrepo
# 9518             3      2   183                Engativa
# 9519             3      1    52                 Tintala
#
#                                          UPZ            Valor Moneda  \
# 0         CHAPINERO: Pardo Rubio + Chapinero    $ 360.000.000      $
# 1                KENNEDY: Castilla + Bavaria    $ 670.000.000      $
# 2         CHAPINERO: Chicó Lago + El Refugio  $ 1.120.000.000      $
# 3                                    Usaquén    $ 890.000.000      $
# 4      USAQUÉN: Country Club + Santa Bárbara    $ 970.000.000      $
# ...                                      ...              ...    ...
# 9515                         Kennedy Central    $ 290.000.000      $
# 9516  SANTA FE: Las Nieves + Sagrado Corazón    $ 670.000.000      $
# 9517                                Restrepo    $ 900.000.000      $
# 9518                                Engativá    $ 335.000.000      $
# 9519                                 Tintala    $ 144.990.000      $
#
#           Precio  Precio_Millon  Precio/M2  Precio_M2
# 0      360000000         360.00       5.14       5.14
# 1      670000000         670.00       3.94       3.94
# 2     1120000000        1120.00       7.78       7.78
# 3      890000000         890.00       5.78       5.78
# 4      970000000         970.00       7.58       7.58
# ...          ...            ...        ...        ...
# 9515   290000000         290.00       4.14       4.14
# 9516   670000000         670.00       6.70       6.70
# 9517   900000000         900.00       2.35       2.35
# 9518   335000000         335.00       1.83       1.83
# 9519   144990000         144.99       2.79       2.79
#
# [9520 rows x 13 columns]

# %%
plt.figure(figsize=(10,8))
grafica = sns.histplot(data = inmuebles, x="Precio_M2", kde = True, hue = "Tipo")
grafica.set_title("Distribución de los valores los precios por metro cuadrado")
plt.xlim((0,20))
#plt.savefig("Ruta", format = "png")
plt.show()

# %%
inmuebles.describe()
# Out:
#        Habitaciones   Baños      Área  Precio_Millon  Precio/M2
# count       9520.00 9520.00   9520.00        9520.00    9520.00
# mean           3.07    2.45    146.66         602.06       5.01
# std            2.05    1.26   1731.38         704.60       2.37
# min            1.00    0.00      2.00          60.00       0.01
# 25%            2.00    2.00     57.00         250.00       3.48
# 50%            3.00    2.00     80.00         409.18       4.67
# 75%            3.00    3.00    135.00         680.00       6.12
# max          110.00    9.00 166243.00       16000.00      90.00

# %%
inmuebles.loc[inmuebles.Precio_M2 >= 40]
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8401  Apartamento       Apartamento en venta en San Cristobal             3
# 9256  Apartamento  Apartamento en venta en Rafael Uribe Uribe             2
#
#       Baños  Área              Barrio            UPZ          Valor Moneda  \
# 8401      1     2       San Cristobal        Sosiego  $ 180.000.000      $
# 9256      1     5  Rafael Uribe Uribe  Los Alcázares  $ 200.000.000      $
#
#          Precio  Precio_Millon  Precio/M2  Precio_M2
# 8401  180000000         180.00      90.00      90.00
# 9256  200000000         200.00      40.00      40.00

# %% [markdown]
# Graficando
#
# ---

# %%
plt.figure(figsize=(10,8))
grafica = sns.histplot(data = inmuebles, x="Precio_Millon", kde = True, hue ="Tipo")
grafica.set_title("Distribución de los valores de los inmuebles en Bogotá")
plt.xlim((50,1000))
#plt.savefig("Ruta", format = "png")
plt.show()
